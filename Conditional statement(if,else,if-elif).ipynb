# %%
# Easy
# Check if a number is positive, negative, or zero.
# Check whether a number is even or odd.
# Find the greater of two numbers.
# Check if a person is eligible to vote (age ≥ 18).
# Check whether a number is divisible by 5.
# Find the largest of three numbers.
# Check if a year is a leap year.
# Check whether a character is a vowel or consonant.
# Check if a number is a multiple of both 3 and 5.
# Check whether a person can apply for a driving license (age ≥ 18).

# %%
# Check if a number is positive, negative, or zero.
number = float(input("enter the number:"))
if number>0:
    print("Number is Positive")
elif number< 0:
    print("Number is Negative")
else:
    print("Number is zero")
# Out:
# Number is Negative

# %%
# Check whether a number is even or odd.
number = int(input("enter the number:"))
if number%2==0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Number is odd

# %%
# Find the greater of two numbers.
number1 = float(input("enter the number:"))
number2 = float(input("enter the number:"))

if number1>number2:
    print("number1 is greater than number2")
elif  number1<number2:
    print("number1 is less than number2")
else:
    print("number1 is equal to number2")
# Out:
# number1 is less than number2

# %%
# Check if a person is eligible to vote (age ≥ 18).
Age = int(input("Enter the age:"))
if Age>= 18:
    print("You're eligible to vote")
else: 
    print("You're not eligible to vote")
# Out:
# You're eligible to vote

# %%
# Check whether a number is divisible by 5.
Number = int(input("enter the number: "))
if Number %5==0:
    print("The number is divisible by 5")
else:
    print("The number is not divisible by 5");
# Out:
# The number is not divisible by 5

# %%
# Find the largest of three numbers.
number1 = int(input("enter number1: "))
number2 = int(input("enter number2: "))
number3 = int(input("enter number3: "))
if number1>number2 and number1>number3:
    print("number1 is the largest")
elif number2>number1 and number2>number3:
    print(" number2 is the largest")
else:
    print("number3 is the largest")
# Out:
# number3 is the largest

# %%
# Check if a year is a leap year.
year = int(input("enter the year:"))
if year%400==0:
    print("It's a leap year")
elif year%100==0:
    print("It's not a leap year")
if year%4==0:
    print("It's a leap year")
else:
    print("It's not a leap year")
# Out:
# It's not a leap year

# %%
# Check whether a character is a vowel or consonant.
character = str(input("enter the character: ")).lower()
if len(character) !=1:
    print("please enter only one character")
elif character in ('a,e,i,o,u'):
    print("Vowel")
else:
    print("Cosonant")
# Out:
# please enter only one character

# %%
# Check if a number is a multiple of both 3 and 5.
number = int(input("enter the number:"))
if number%3==0 and number%5==0:
    print("nmuber is a multiple of both 3 and 5")
else:
    print("number is not a multiple of both 3 and 5");
# Out:
# number is not a multiple of both 3 and 5

# %%
# Check whether a person can apply for a driving license (age ≥ 18).
Person_age = int(input("enter the person age: "))
if Person_age>=18:
    print("person can apply for driving license")
else:
    print("person can't apply for driving license")
# Out:
# person can't apply for driving license

# %%
# 11.Smallest of three numbers
number1 = int(input("enter number1: "))
number2 = int(input("enter number2: "))
number3 = int(input("enter number3: "))
if number1<number2 and number1<number3:
    print("number1 is the smallest")
elif number2<number1 and number2<number3:
    print(" number2 is the smallest")
else:
    print("number3 is the smallest")
# Out:
# number1 is the largest

# %%
# 12.Grade calculator
marks = float(input("enter the marks out of 100"))
if marks>=90:
    print('your grade is A+')
elif marks>=75:
    print('your grade is A')
elif marks>=60:
    print('your grade is B')
elif marks>=34:
    print('your grade is C')
else:
    print("You're fail")
# Out:
# your grade is B

# %%
# Check positive even/positive odd/negative
number = int(input("enter the number: "))
if number>0:
    if number%2==0:
        print('Positive even')
    else:
        print("Positive odd")
elif number<0:
    if number%2==0:
        print("Negative even")
    else:
        print("Negative odd")
else:
    print("Zero")
# Out:
# Positive odd

# %%
# Check whether a number is 1, 2, 3, or 4 digit
number = int(input("enter the number:"))
number = abs(number) # abs- removes the negative signs for numbers
if number<=9:
    print("number is one digit")
elif number<=99:
    print("number is two digit")
elif number<=999:
    print("number is three digit")
elif  number<=9999:
    print("number is four digit")
else:
    print("number is outside the range")
# Out:
# number is two digit

# %%
# Check whether a character is uppercase/lowercase
character = str(input("enter the char: "))
if character.isupper():
    print("Char is uppercase")
elif character.islower():
    print("Char is lowercase")
else:
    print("Char is outside the range")
# Out:
# Char is uppercase

# %%
# Check whether a year is leap year
year = int(input('enter the year: '))
if year % 400 == 0:
    print("It's a leap year")
elif year % 100 ==0:
    print("It's not a leap year")
elif year % 4==0:
    print("It's a leap year")
else:
    print("enter the correct year")
# Out:
# It's a leap year

# %%
# Check whether three sides form a valid triangle
a = int(input("enter the number: "))
b= int(input("enter the number: "))
c = int(input("enter the number: "))
if a+b>c and a+c>b and b+c>a:
    print("valid triangle")
else:
    print("Invalid triangle")
# Out:
# valid triangle

# %%
# Classify triangle: equilateral/isosceles/scalene
# Equilateral → all three sides are equal
# Isosceles → any two sides are equal
# Scalene → all three sides are different
a = int(input("enter side a: "))
b = int(input("enter side b: "))
c = int(input("enter side c: "))
if  a==b==c:
    print("Equilateral")
elif a==b or b==c or c==a:
    print("Isoceles")
else:
    print("Scalene");
# Out:
# Scalene

# %%
# Simple calculator using if-elif-else
a = float(input("enter the first number:"))
b = float(input("enter the second number:"))
operator = input("enter the operator(+,-,*,/): ")
if operator == "+":
    print(a + b)
elif operator == "-":
    print(a - b)
elif operator == "*":
    print(a * b)
elif operator == "/":
    print(a / b)
else:
    print("please enter the correct operator")
# Out:
# 20.0

# %%
# Electricity bill calculator
units = int(input("enter electricity units: "))
if units<=100:
    bill = units*5
elif units<=200:
    bill = (100*5)+((units-100)*7)
else:
    bill=(100*5)+(100*7)+((units-200)*10)
print("Electricity Bill =",bill)
# Out:
# Electricity Bill = 3700
